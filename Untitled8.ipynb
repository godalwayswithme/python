# %%
1. Who developed Python Programming Language?

Python programming language was developed by Guido van Rossum. He started working on Python in the late 1980s and released its first version, Python 0.9.0, in February 1991. Van Rossum designed Python to be easy to read, with a clean syntax and powerful features, drawing inspiration from languages like ABC, C, and Modula-3. Python's philosophy emphasizes code readability and simplicity, making it widely popular for beginners and experienced programmers alike.







2. Which type of Programming does Python support?
Python supports multiple programming paradigms, making it a versatile language. The key programming paradigms supported by Python include:

Object-Oriented Programming (OOP): Python allows the use of objects and classes to structure code in a modular and reusable way.

Procedural Programming: Python supports procedural programming, which organizes code into procedures or routines (functions).

Functional Programming: Python has first-class functions and supports functional programming concepts, like higher-order functions, anonymous functions (lambda), map, filter, and reduce.

Aspect-Oriented Programming (AOP): Python can support AOP to modularize cross-cutting concerns, though it's less commonly used.

Scripting: Python can be used for scripting, automating tasks and writing small utility programs.

Dynamic Programming: Python supports dynamic typing and dynamic memory management.

These diverse paradigms make Python highly flexible for various applications, including web development, data science, automation, and more.







3. Is Python case sensitive when dealing with identifiers?
4. What is the correct extension of the Python file?
Yes, Python is case sensitive when dealing with identifiers. This means that variable names, function names, and other identifiers must be used with consistent capitalization. For example, MyVariable, myvariable, and MYVARIABLE would be treated as three different identifiers in Python.

The correct extension for a Python file is .py. Python scripts or modules are saved with this extension, allowing them to be executed by the Python interpreter.







5. Is Python code compiled or interpreted?
6. Name a few blocks of code used to define in Python language?

Python is primarily an interpreted language. When you run Python code, it is first compiled into an intermediate bytecode, which is then interpreted by the Python Virtual Machine (PVM). This process allows for dynamic execution and debugging, but Python is not typically considered a compiled language like C or Java.

In Python, code blocks are defined by indentation, rather than curly braces or keywords. Some of the commonly used blocks of code include:

Function block: Defined using the def keyword, followed by the function name and parameters.

python
Copy code
def my_function():
    # code block inside the function
    print("Hello, world!")
Class block: Defined using the class keyword, followed by the class name.

python
Copy code
class MyClass:
    # code block inside the class
    def method(self):
        print("This is a method.")
Conditional block: Defined using if, elif, and else statements.

python
Copy code
if condition:
    # code block for true condition
    print("Condition is true")
else:
    # code block for false condition
    print("Condition is false")
Loop block: Defined using for or while loops.

python
Copy code
for i in range(5):
    # code block inside the loop
    print(i)
In each of these cases, the block of code is denoted by indentation rather than explicit symbols like {} used in other languages.







7. State a character used to give single-line comments in Python?

In Python, a hash symbol (#) is used to give single-line comments. Anything following the # on that line will be treated as a comment and will not be executed by the interpreter. For example:

python
Copy code
# This is a single-line comment
print("Hello, world!")  # This comment is after a statement
Comments are useful for explaining code or making notes without affecting the program's functionality.






8. Mention functions which can help us to find the version of python that we are currently working on?

You can find the version of Python you are currently working on by using the following functions from the sys module:

sys.version: This function returns a string containing the version number of the Python interpreter along with additional information about the build.

python
Copy code
import sys
print(sys.version)
sys.version_info: This function returns a tuple containing the version number as integers, allowing for easy comparison. It provides the major, minor, micro, release level, and serial.

python
Copy code
import sys
print(sys.version_info)
For example, the output of sys.version_info might look like this:

python
Copy code
sys.version_info(major=3, minor=10, micro=5, releaselevel='final', serial=0)
These functions are useful for checking the Python version programmatically, especially when compatibility is a concern in your code.







9. Python supports the creation of anonymous functions at runtime, using a construct called
10. What does pip stand for python?
11. Mention a few built-in functions in python?
12. What is the maximum possible length of an identifier in Python?
13. What are the benefits of using Python?
14. How is memory managed in Python?
15. How to install Python on Windows and set path variables? 16. Is indentation required in python?


Python supports the creation of anonymous functions at runtime using a construct called lambda. A lambda function can take any number of arguments but can only have one expression. For example:

python
Copy code
square = lambda x: x ** 2
print(square(5))  # Output: 25
Pip stands for "Pip Installs Packages" or "Pip Installs Python". It is the package installer for Python, allowing you to install and manage additional libraries and dependencies that are not part of the standard library.

A few built-in functions in Python include:

print(): Outputs text to the console.
len(): Returns the length of an object (like a string, list, or tuple).
type(): Returns the type of an object.
sum(): Returns the sum of a collection of numbers.
max(): Returns the largest item in an iterable or the largest of two or more arguments.
min(): Returns the smallest item in an iterable or the smallest of two or more arguments.
The maximum possible length of an identifier in Python is 79 characters. However, it's a good practice to keep identifiers concise and meaningful for readability.

Benefits of using Python include:

Easy to Learn and Use: Python has a simple syntax that is easy for beginners to understand.
Versatile and Flexible: Python can be used for various applications, including web development, data analysis, artificial intelligence, and more.
Rich Ecosystem of Libraries and Frameworks: Python has a vast standard library and many third-party libraries that simplify complex tasks.
Strong Community Support: Python has a large and active community, making it easier to find resources, tutorials, and help.
Cross-Platform Compatibility: Python runs on various operating systems, including Windows, macOS, and Linux.
Memory management in Python is handled by the Python memory manager. It uses a combination of reference counting and a garbage collection system to manage memory.
Reference Counting: Each object has a reference count that keeps track of how many references point to that object. When the reference count drops to zero, the memory occupied by the object is released.
Garbage Collection: Python also uses a cyclic garbage collector to detect and collect objects that are no longer reachable, even if they are part of a reference cycle.
To install Python on Windows and set path variables:

Download the Python installer from the official Python website.

Run the installer. Make sure to check the box that says "Add Python to PATH" before proceeding.

Follow the installation instructions.

After installation, verify the installation by opening Command Prompt and typing python --version. This should display the installed Python version.

If you didn’t add Python to the PATH during installation, you can do it manually by going to System Properties > Advanced > Environment Variables. Under System Variables, find the Path variable, and add the path to the Python installation directory (e.g., C:\Python39).

Yes, indentation is required in Python. Unlike many other programming languages that use braces or keywords to define code blocks, Python uses indentation to denote blocks of code. Proper indentation is crucial for the correct execution of the code, as it defines the scope of loops, functions, classes, and conditionals. For example:

python
Copy code
if condition:
    # Indented block
    print("Condition is true")
